# %% [markdown]
# # Análisis exploratorio AquaLimpia S. A.
#
# Este notebook presenta el análisis exploratorio desarrollado para AquaLimpia S. A., empresa dedicada al tratamiento de aguas residuales urbanas e industriales.
#
# El objetivo es revisar el desempeño de las plantas de tratamiento, calcular indicadores operacionales y ambientales, evaluar la calidad de los datos y generar archivos de salida que apoyen la toma de decisiones.

# %%
from pathlib import Path
import os
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd()

if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

os.chdir(PROJECT_ROOT)
sys.path.append(str(PROJECT_ROOT / "src"))

print("Carpeta de trabajo:", PROJECT_ROOT)
# Out:
# Carpeta de trabajo: c:\Users\Diegoh\Desktop\iacc\ciencia de datos\Semana 8

# %%
from main import DATA_PATH, OUTPUT_DIR, cargar_datos
from analisis_utils import (
    preparar_indicadores,
    evaluar_calidad_datos,
    generar_resumen_por_planta,
    calcular_correlacion_spearman
)

df = cargar_datos(DATA_PATH)
df.head()
# Out:
#   fecha_registro         planta  caudal_entrada_m3_d  DBO_entrada_mg_L  \
# 0     2025-08-17     Planta Sur                 6562               271
# 1     2025-09-07     Planta Sur                 5336               322
# 2     2025-07-26   Planta Norte                 5755               318
# 3     2025-10-27  Planta Centro                 6840               216
# 4     2025-09-06  Planta Centro                 6803               326
#
#    SST_entrada_mg_L  pH_entrada  energia_aeracion_kWh  lodos_generados_kg_d  \
# 0               324        7.12                1261.1                 440.3
# 1               230        7.01                1629.3                 561.2
# 2               282        6.79                1469.2                 441.6
# 3               167        7.01                1764.8                 560.0
# 4               200        7.55                1409.3                 654.0
#
#    DBO_salida_mg_L  cumplimiento_norma
# 0             40.0                   0
# ...

# %%
df.info()

# %%
df_preparado = preparar_indicadores(df)
df_preparado.head()

# %%
reporte_calidad = evaluar_calidad_datos(df)
reporte_calidad

# %%
resumen = generar_resumen_por_planta(df_preparado)
resumen

# %%
correlacion = calcular_correlacion_spearman(
    df_preparado,
    "caudal_entrada_m3_d",
    "DBO_salida_mg_L"
)

correlacion

# %% [markdown]
# ## Conclusión
#
# El análisis permitió organizar el dataset, calcular indicadores relevantes, evaluar la calidad de los datos y generar archivos de salida para distintas áreas de AquaLimpia S. A.
#
# Los resultados se presentan en reportes CSV, un dashboard HTML y documentación técnica disponible en el repositorio GitHub del proyecto.
